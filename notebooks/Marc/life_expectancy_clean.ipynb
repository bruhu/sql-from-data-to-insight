# %%
import pandas as pd
dataset = '/Users/marcgreenlee/Desktop/Ironhack/ironhack_projects/Project3_world_happiness/sql-from-data-to-insight/data/raw/life_expectancy_data.csv'

df = pd.read_csv(dataset)
df
# Out:
#                            Unnamed: 0 Unnamed: 1  \
# 0    Countries, territories and areas       Year
# 1                         Afghanistan       2019
# 2                         Afghanistan       2015
# 3                         Afghanistan       2010
# 4                         Afghanistan       2000
# ..                                ...        ...
# 728                            Zambia       2000
# 729                          Zimbabwe       2019
# 730                          Zimbabwe       2015
# 731                          Zimbabwe       2010
# 732                          Zimbabwe       2000
#
#     Life expectancy at birth (years) Life expectancy at birth (years).1  \
# 0                         Both sexes                               Male
# 1                               63.2                               63.3
# 2                               61.7                               61.0
# 3                               59.9                               59.6
# ...

# %%
df2019 = df[df['Unnamed: 1'].isin(['2019', 'Year'])]
df2019
# Out:
#                              Unnamed: 0 Unnamed: 1  \
# 0      Countries, territories and areas       Year
# 1                           Afghanistan       2019
# 5                               Albania       2019
# 9                               Algeria       2019
# 13                               Angola       2019
# ..                                  ...        ...
# 713  Venezuela (Bolivarian Republic of)       2019
# 717                            Viet Nam       2019
# 721                               Yemen       2019
# 725                              Zambia       2019
# 729                            Zimbabwe       2019
#
#     Life expectancy at birth (years) Life expectancy at birth (years).1  \
# 0                         Both sexes                               Male
# 1                               63.2                               63.3
# 5                               78.0                               76.3
# ...

# %%
df2019['Unnamed: 0'].duplicated().sum()
# Out:
# 0

# %%
df2019.drop(['Life expectancy at birth (years).1', 'Life expectancy at birth (years).2', 'Life expectancy at age 60 (years)', 'Life expectancy at age 60 (years).1', 'Life expectancy at age 60 (years).2', 'Healthy life expectancy (HALE) at birth (years).1', 'Healthy life expectancy (HALE) at birth (years).2', 'Healthy life expectancy (HALE) at age 60 (years)', 'Healthy life expectancy (HALE) at age 60 (years).1',	'Healthy life expectancy (HALE) at age 60 (years).2'], axis = 1, inplace = True) 

df2019
# Out:
# /var/folders/g8/09hltth967b7q64rp00g_5mc0000gn/T/ipykernel_29115/3274168323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2019.drop(['Life expectancy at birth (years).1', 'Life expectancy at birth (years).2', 'Life expectancy at age 60 (years)', 'Life expectancy at age 60 (years).1', 'Life expectancy at age 60 (years).2', 'Healthy life expectancy (HALE) at birth (years).1', 'Healthy life expectancy (HALE) at birth (years).2', 'Healthy life expectancy (HALE) at age 60 (years)', 'Healthy life expectancy (HALE) at age 60 (years).1',	'Healthy life expectancy (HALE) at age 60 (years).2'], axis = 1, inplace = True)
#                              Unnamed: 0 Unnamed: 1  \
# 0      Countries, territories and areas       Year
# 1                           Afghanistan       2019
# ...

# %%
df2019.columns = ['Country', 'Year', 'Life Expectancy at Birth (Both Sexes)', 'Healthy Life Expectancy at Birth (Both Sexes)']
df2019
# Out:
#                                 Country  Year  \
# 0      Countries, territories and areas  Year
# 1                           Afghanistan  2019
# 5                               Albania  2019
# 9                               Algeria  2019
# 13                               Angola  2019
# ..                                  ...   ...
# 713  Venezuela (Bolivarian Republic of)  2019
# 717                            Viet Nam  2019
# 721                               Yemen  2019
# 725                              Zambia  2019
# 729                            Zimbabwe  2019
#
#     Life Expectancy at Birth (Both Sexes)  \
# 0                              Both sexes
# 1                                    63.2
# 5                                    78.0
# 9                                    77.1
# 13                                   63.1
# ..                                    ...
# 713                                  73.9
# 717                                  73.7
# ...

# %%
df2019.sort_values(by= 'Life Expectancy at Birth (Both Sexes)', ascending = False, inplace = True)
# Out:
# /var/folders/g8/09hltth967b7q64rp00g_5mc0000gn/T/ipykernel_29115/2818771910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2019.sort_values(by= 'Life Expectancy at Birth (Both Sexes)', ascending = False, inplace = True)

# %%
df2019.reset_index(drop=True, inplace=True)
df2019
# Out:
#                               Country  Year  \
# 0    Countries, territories and areas  Year
# 1                               Japan  2019
# 2                         Switzerland  2019
# 3                   Republic of Korea  2019
# 4                           Singapore  2019
# ..                                ...   ...
# 179                        Mozambique  2019
# 180                          Eswatini  2019
# 181                           Somalia  2019
# 182          Central African Republic  2019
# 183                           Lesotho  2019
#
#     Life Expectancy at Birth (Both Sexes)  \
# 0                              Both sexes
# 1                                    84.3
# 2                                    83.4
# 3                                    83.3
# 4                                    83.2
# ..                                    ...
# 179                                  58.1
# 180                                  57.7
# 181                                  56.5
# ...

# %%
df2019.drop(0, axis = 0, inplace = True)
# Out:
# /var/folders/g8/09hltth967b7q64rp00g_5mc0000gn/T/ipykernel_29115/1399291978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2019.drop(0, axis = 0, inplace = True)

# %%
df2019
# Out:
#                       Country  Year Life Expectancy at Birth (Both Sexes)  \
# 1                       Japan  2019                                  84.3
# 2                 Switzerland  2019                                  83.4
# 3           Republic of Korea  2019                                  83.3
# 4                   Singapore  2019                                  83.2
# 5                       Spain  2019                                  83.2
# ..                        ...   ...                                   ...
# 179                Mozambique  2019                                  58.1
# 180                  Eswatini  2019                                  57.7
# 181                   Somalia  2019                                  56.5
# 182  Central African Republic  2019                                  53.1
# 183                   Lesotho  2019                                  50.7
#
#     Healthy Life Expectancy at Birth (Both Sexes)
# ...
